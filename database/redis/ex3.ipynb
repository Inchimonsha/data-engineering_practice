# %% [markdown]
# ## Создание очередей задач с помощью списков Redis
#
# Задача: реализовать очередь обработки заданий, например, для email-рассылки или обработки изображений.
#
# Цель: добавить задачи в очередь (LPUSH), обработать их по порядку (RPOP).
#
# Полезно для построения систем с асинхронной обработкой
