# %% [markdown]
# ## Подсчет статистики событий в реальном времени
#
# Задача: считать количество просмотров, лайков или других действий пользователей с использованием счетчиков Redis (INCR, DECR).
#
# Подходит для аналитики и дашбордов, которые требуют высокой скорости обновления
