# %% [markdown]
# Простое кэширование данных модели
#
#     Задание: Реализуйте кэширование результатов предсказаний модели машинного обучения в Redis. Храните предсказания для входных данных с уникальным ключом и настройте время жизни кэша (TTL).
#
#     Цель: Научиться сохранять и извлекать результаты из кэша для ускорения повторных запросов.
