# %% [markdown]
# ## Практическая лабораторная работа с командами Redis
#
# Задача: использовать redis-cli для выполнения основных команд по работе со строками, списками, множества, хешами и отсортированными множествами.
#
# Цель: понять, как хранить, извлекать, модифицировать данные разных типов
