# %% [markdown]
# ## Организация блокировок (Mutex) для распределенных систем
#
# Задача: с помощью Redis реализовать механизм блокировки ресурса, чтобы избежать гонок данных при параллельном доступе.
#
# Используются команды SETNX, EXPIRE.
#
# Кейс полезен при построении систем с несколькими потребителями
