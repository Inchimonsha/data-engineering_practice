# %% [markdown]
# ## Проект: Логирование и анализ веб-трафика
#
# Захватите логи веб-сервера с полями IP, время, URL, user-agent.
#
# Создайте таблицу для хранения логов.
#
# Постройте аналитические запросы: количество уникальных посетителей за день, наиболее посещаемые страницы, время пикового трафика.
