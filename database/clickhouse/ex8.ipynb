# %% [markdown]
# ## Оптимизация хранения и запросов
#
# Экспериментируйте с разными движками таблиц: MergeTree, AggregatingMergeTree, SummingMergeTree.
#
# Создайте агрегатные таблицы для ускорения запросов.
