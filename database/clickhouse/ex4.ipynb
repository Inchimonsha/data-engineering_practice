# %% [markdown]
# ## Использование Join-операций для аналитики
#
# Объедините данные из двух таблиц — например, таблицу пользователей и таблицу заказов — с использованием INNER JOIN, LEFT JOIN.
#
# Изучите, как оптимизировать join-операции, чтобы они были эффективными с большой базой.
