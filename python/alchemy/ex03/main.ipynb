# %%
import os
from dotenv import load_dotenv
import json
import asyncpg
from datetime import datetime
from typing import Optional, Annotated, Sequence, Any, Dict, List
from redis.asyncio import Redis
from sqlalchemy import ARRAY, JSON, Integer, String, ForeignKey, Text, func, text
from sqlalchemy.orm import DeclarativeBase, declared_attr, Mapped, mapped_column
from sqlalchemy.ext.asyncio import AsyncAttrs, async_sessionmaker, create_async_engine
from pgvector.sqlalchemy import Vector
import tiktoken
from langchain_openai import ChatOpenAI
from langchain_gigachat.chat_models import GigaChat
from langchain_gigachat.embeddings import GigaChatEmbeddings

# %%
load_dotenv()

POSTGRES_URL = os.environ.get("POSTGRES_URL")
GIGACHAT_API_KEY = os.environ.get("GIGACHAT_API_KEY")

# %%
embedder = GigaChatEmbeddings(
    credentials=GIGACHAT_API_KEY,
    verify_ssl_certs=False
)

# %%
engine = None
async_session_maker = None


class Base(AsyncAttrs, DeclarativeBase):
    __abstract__ = True
    __table_args__ = {'schema': 'ksu_test'}

    id: Mapped[int] = mapped_column(Integer, primary_key=True, autoincrement=True)
    created_at: Mapped[datetime] = mapped_column(server_default=func.now())
    updated_at: Mapped[datetime] = mapped_column(server_default=func.now(), onupdate=func.now())

    @declared_attr.directive
    def __tablename__(cls) -> str:
        return cls.__name__.lower() + 's'


def connection(method):
    async def wrapper(*args, **kwargs):
        async with async_session_maker() as session:
            try:
                async with session.begin():
                    return await method(*args, session=session, **kwargs)
            except Exception as e:
                await session.rollback()
                raise
            finally:
                await session.close()

    return wrapper


async def init_db():
    global engine, async_session_maker
    engine = create_async_engine(url=POSTGRES_URL)

    async_session_maker = async_sessionmaker(engine, expire_on_commit=False)

async def create_tables():
    async with engine.begin() as conn:
        await conn.execute(text("CREATE EXTENSION IF NOT EXISTS vector;"))
        await conn.execute(text("CREATE SCHEMA IF NOT EXISTS ksu_test"))
        await conn.run_sync(Base.metadata.create_all)
async def create_indexes():
    async with engine.begin() as conn:
        # Создание индекса для вектора с использованием ivfflat
        await conn.execute(text("""
            CREATE INDEX IF NOT EXISTS idx_document_embedding
            ON ksu_test.documents
            USING ivfflat (embedding vector_cosine_ops);
        """))

# %%
class Document(Base):
    message_number: Mapped[int] = mapped_column(Integer, nullable=False)
    content: Mapped[str] = mapped_column(Text, nullable=False)
    category: Mapped[str] = mapped_column(String(50), nullable=False)
    subcategory: Mapped[str] = mapped_column(String(50), nullable=False)
    meta: Mapped[Dict[str, Any]] = mapped_column("metadata", JSON, nullable=True)
    embedding: Mapped[List[float]] = mapped_column(Vector(1024), nullable=False)

# %%
def chunk_text_with_overlap(
        text: str,
        max_tokens: int = 500,
        overlap_tokens: int = 100) -> list[str]:
    '''
    Разбивает текст на чанки с перекрытием по токенам
    '''
    enc = tiktoken.get_encoding("cl100k_base")
    tokens = enc.encode(text)
    chunks = []
    start = 0

    while start < len(tokens):
        end = min(start + max_tokens, len(tokens))
        chunk_tokens = tokens[start:end]
        chunk_text = enc.decode(chunk_tokens)
        chunks.append(chunk_text)
        start += max_tokens - overlap_tokens

    return chunks

# %%
@connection
async def generate_embeddings(corpus_path: str = "corpus.json", session=None):
    corpus = json.load(open(corpus_path, "r", encoding="utf-8"))
    docs = []

    for data in corpus:
        chunks = chunk_text_with_overlap(
            data["content"],
            max_tokens=500,
            overlap_tokens=100
        )
        print(data.get("metadata", {}))
        for idx, chunk in enumerate(chunks):
            embedding_vector = embedder.embed_query(chunk)

            db_document = Document(
                message_number=data.get("message_number", -1),
                content=chunk,
                category=data.get("category", ""),
                subcategory=data.get("subcategory", ""),
                meta=json.dumps(data.get("metadata", {})),
                embedding=embedding_vector
            )
            docs.append(db_document)
            
            # Батчинг каждые 100 документов
            # if len(docs) >= 100:
            #     session.add_all(docs)
            #     await session.flush()  # Не коммитим, только flush
            #     docs.clear()

    session.add_all(docs)
    await session.commit()

# %%
await init_db()

# %%
await create_tables()

# %%
await create_indexes()

# %%
await generate_embeddings()
# Out:
# {'tags': ['ошибка', 'непонимание', 'системное'], 'updated_at': '2025-07-15T10:16:00+03:00', 'buttons': [{'title': '🏠 В начало', 'go_to': 11}], 'transitions': {'default': 11}}
# {'tags': ['приветствие', 'главное меню'], 'updated_at': '2025-07-15T10:00:00+03:00', 'buttons': [{'title': 'О чём ты хочешь узнать?', 'go_to': 11}, {'title': 'Как подготовиться к поступлению', 'go_to': 21}, {'title': 'О поступлении', 'go_to': 2}], 'transitions': {'default': 11}}
# {'tags': ['поступление', 'контакты'], 'updated_at': '2025-07-15T10:00:00+03:00', 'buttons': [{'title': 'Какой проходной балл?', 'go_to': 5}, {'title': 'Сколько мест для приема на 2024-2025 учебный год?', 'go_to': 31}], 'transitions': {}}
# {'tags': ['поступление', 'проходные баллы'], 'updated_at': '2025-07-15T10:04:00+03:00', 'buttons': [{'title': '🏠 В начало', 'go_to': 11}], 'transitions': {'default': 11}}
# {'tags': ['поступление', 'сроки'], 'updated_at': '2025-07-15T10:04:00+03:00', 'buttons': [{'title': '🏠 В начало', 'go_to': 11}], 'transitions': {'default': 11}}
# {'tags': ['поступление', 'документы', 'подача'], 'updated_at': '2025-07-15T10:04:00+03:00', 'buttons': [{'title': '🏠 В начало', 'go_to': 11}], 'transitions': {'default': 11}}
# {'tags': ['поступление', 'документы', 'требования'], 'updated_at': '2025-07-15T10:04:00+03:00', 'buttons': [{'title': '🏠 В начало', 'go_to': 11}], 'transitions': {'default': 11}}
# {'tags': ['поступление', 'индивидуальные достижения'], 'updated_at': '2025-07-15T10:04:00+03:00', 'buttons': [{'title': '🏠 В начало', 'go_to': 11}], 'transitions': {'default': 11}}
# {'tags': ['поступление', 'рейтинг'], 'updated_at': '2025-07-15T10:04:00+03:00', 'buttons': [{'title': '🏠 В начало', 'go_to': 11}], 'transitions': {'default': 11}}
# {'tags': ['обучение', 'меню'], 'updated_at': '2025-07-15T10:05:00+03:00', 'buttons': [{'title': 'Есть ли стипендия?', 'go_to': 32}, {'title': 'В каких корпусах проходят занятия?', 'go_to': 12}, {'title': 'Предоставляется ли общежитие?', 'go_to': 13}, {'title': 'Есть ли военная кафедра?', 'go_to': 14}, {'title': 'Есть ли столовая?', 'go_to': 15}, {'title': 'Какие есть направленности/профили?', 'go_to': 16}, {'title': 'Есть ли магистратура?', 'go_to': 17}, {'title': 'Кто меня будет учить?', 'go_to': 34}, {'title': 'Как я могу прославиться еще во время учебы?', 'go_to': 33}, {'title': 'Чем я смогу заниматься помимо учебы?', 'go_to': 23}, {'title': '🏠 В начало', 'go_to': 11}], 'transitions': {}}
# {'tags': ['обучение', 'корпус'], 'updated_at': '2025-07-15T10:05:00+03:00', 'buttons': [{'title': '🏠 В начало', 'go_to': 11}], 'transitions': {'default': 11}}
# {'tags': ['общежитие', 'иногородним'], 'updated_at': '2025-07-15T10:05:00+03:00', 'buttons': [{'title': '🏠 В начало', 'go_to': 11}], 'transitions': {'default': 11}}
# {'tags': ['военная кафедра', 'обучение'], 'updated_at': '2025-07-15T10:05:00+03:00', 'buttons': [{'title': '🏠 В начало', 'go_to': 11}], 'transitions': {'default': 11}}
# {'tags': ['столовая', 'корпус Е'], 'updated_at': '2025-07-15T10:05:00+03:00', 'buttons': [{'title': '🏠 В начало', 'go_to': 11}], 'transitions': {'default': 11}}
# {'tags': ['обучение', 'профили'], 'updated_at': '2025-07-15T10:05:00+03:00', 'buttons': [{'title': 'Расскажи подробнее!', 'go_to': 18}], 'transitions': {'default': 18}}
# {'tags': ['профили', 'детали'], 'updated_at': '2025-07-15T10:05:00+03:00', 'buttons': [{'title': '🏠 В начало', 'go_to': 11}], 'transitions': {'default': 11}}
# {'tags': ['магистратура', 'продолжение'], 'updated_at': '2025-07-15T10:05:00+03:00', 'buttons': [{'title': '🏠 В начало', 'go_to': 11}], 'transitions': {'default': 11}}
# {'tags': ['трудоустройство', 'меню'], 'updated_at': '2025-07-15T10:06:00+03:00', 'buttons': [{'title': 'Где могут работать ваши выпускники?', 'go_to': 19}, {'title': 'Кем могут работать ваши выпускники?', 'go_to': 35}, {'title': 'Расскажи про успешных выпускников', 'go_to': 20}], 'transitions': {}}
# {'tags': ['трудоустройство', 'работодатели', 'практика'], 'updated_at': '2025-07-15T10:06:00+03:00', 'buttons': [], 'transitions': {}}
# {'tags': ['трудоустройство', 'успешные выпускники'], 'updated_at': '2025-07-15T10:06:00+03:00', 'buttons': [{'title': '🏠 В начало', 'go_to': 11}], 'transitions': {'default': 11}}
# {'tags': ['поступление', 'подготовка'], 'updated_at': '2025-07-15T10:07:00+03:00', 'buttons': [{'title': 'Есть ли курсы по подготовке к ЕГЭ?', 'go_to': 28}, {'title': 'Когда день открытых дверей?', 'go_to': 29}, {'title': '🏠 В начало', 'go_to': 11}], 'transitions': {'default': 11}}
# {'tags': ['контакты', 'приемная комиссия'], 'updated_at': '2025-07-15T10:07:00+03:00', 'buttons': [{'title': '🏠 В начало', 'go_to': 11}], 'transitions': {'default': 11}}
# {'tags': ['внеучебная деятельность', 'студенческая жизнь'], 'updated_at': '2025-07-15T10:08:00+03:00', 'buttons': [{'title': 'Наука', 'go_to': 24}, {'title': 'Спорт', 'go_to': 25}, {'title': 'Общественная деятельность', 'go_to': 26}, {'title': 'Творчество', 'go_to': 27}, {'title': '🏠 В начало', 'go_to': 11}], 'transitions': {'default': 11}}
# {'tags': ['поступление', 'финансовая поддержка'], 'updated_at': '2025-07-15T10:10:00+03:00', 'buttons': [{'title': '🏠 В начало', 'go_to': 11}], 'transitions': {'default': 11}}
# {'tags': ['поступление', 'бюджетные места'], 'updated_at': '2025-07-15T10:10:00+03:00', 'buttons': [{'title': '🏠 В начало', 'go_to': 11}], 'transitions': {'default': 11}}
# {'tags': ['стипендия', 'обучение'], 'updated_at': '2025-07-15T10:12:00+03:00', 'buttons': [{'title': '🏠 В начало', 'go_to': 11}], 'transitions': {'default': 11}}
# {'tags': ['учеба', 'достижения', 'олимпиады', 'хакатоны'], 'updated_at': '2025-07-15T10:12:00+03:00', 'buttons': [{'title': 'Узнать про интенсивы', 'go_to': 36}, {'title': '🏠 В начало', 'go_to': 11}], 'transitions': {'default': 11}}
# {'tags': ['преподаватели', 'обучение'], 'updated_at': '2025-07-15T10:12:00+03:00', 'buttons': [{'title': '🏠 В начало', 'go_to': 11}], 'transitions': {'default': 11}}
# {'tags': ['трудоустройство', 'профессии'], 'updated_at': '2025-07-15T10:13:00+03:00', 'buttons': [{'title': 'Расскажи про направления!', 'go_to': 37}, {'title': '🏠 В начало', 'go_to': 11}], 'transitions': {'default': 11}}
# {'tags': ['проекты', 'интенсивы'], 'updated_at': '2025-07-15T10:13:00+03:00', 'buttons': [{'title': '🏠 В начало', 'go_to': 11}], 'transitions': {'default': 11}}

# %%
from sqlalchemy import select


@connection
async def generate(session=None):
    res = await session.execute(select(Document))
    return res.scalars().all()

res = await generate()

# print(len(res))
# for r in res:
#     print(r.meta)

# %%
@connection
async def search_index(embedding: List[float], top_k: int = 3, session=None) -> List[Dict[str, Any]]:
    embedding_str = '[' + ','.join(map(str, embedding)) + ']'
    query = text(f"""
        SELECT message_number, content, category, subcategory, metadata, embedding,
               1.0 / ((embedding <=> '{embedding_str}'::vector) + 1e-6) AS score
        FROM ksu_test.documents
        ORDER BY embedding <=> '{embedding_str}'::vector
        LIMIT {top_k};
    """)
    result = await session.execute(query)
    return result.mappings().all()

@connection
async def search_content(content, top_k=3, session=None):
    query = text("""
        SELECT message_number, content, category, subcategory, metadata,
               ts_rank_cd(to_tsvector('russian', content), plainto_tsquery('russian', :content)) AS rank
        FROM ksu_test.documents
        WHERE to_tsvector('russian', content) @@ plainto_tsquery('russian', :content)
        ORDER BY rank DESC
        LIMIT :top_k;
    """)
    result = await session.execute(query, {"content": content, "top_k": top_k})
    return result.mappings().all()

# %%
content = "Привет, напиши про буфет"
embedding = embedder.embed_query(content)

res_content = await search_content(content)
for r in res_content:
    print(r)

res = await search_index(embedding)
for r in res:
    print(r)
# Out:
# {'message_number': 4, 'content': 'Информация о трудоустройстве:', 'category': 'Трудоустройство', 'subcategory': 'Основная информация', 'metadata': '{"tags": ["\\u0442\\u0440\\u0443\\u0434\\u043e\\u0443\\u0441\\u0442\\u0440\\u043e\\u0439\\u0441\\u0442\\u0432\\u043e", "\\u043c\\u0435\\u043d\\u044e"], "updated_at": "2025-07-15T10:06:00+03:00", "buttons": [{"title": "\\u0413\\u0434\\u0435 \\u043c\\u043e\\u0433\\u0443\\u0442 \\u0440\\u0430\\u0431\\u043e\\u0442\\u0430\\u0442\\u044c \\u0432\\u0430\\u0448\\u0438 \\u0432\\u044b\\u043f\\u0443\\u0441\\u043a\\u043d\\u0438\\u043a\\u0438?", "go_to": 19}, {"title": "\\u041a\\u0435\\u043c \\u043c\\u043e\\u0433\\u0443\\u0442 \\u0440\\u0430\\u0431\\u043e\\u0442\\u0430\\u0442\\u044c \\u0432\\u0430\\u0448\\u0438 \\u0432\\u044b\\u043f\\u0443\\u0441\\u043a\\u043d\\u0438\\u043a\\u0438?", "go_to": 35}, {"title": "\\u0420\\u0430\\u0441\\u0441\\u043a\\u0430\\u0436\\u0438 \\u043f\\u0440\\u043e \\u0443\\u0441\\u043f\\u0435\\u0448\\u043d\\u044b\\u0445 \\u0432\\u044b\\u043f\\u0443\\u0441\\u043a\\u043d\\u0438\\u043a\\u043e\\u0432", "go_to": 20}], "transitions": {}}', 'embedding': '[0.8598633,-0.3947754,-0.6850586,-0.52490234,1.1806641,-1.0048828,-0.11694336,3.4550781,1.7148438,-0.5439453,0.91015625,0.022567749,-1.4072266,-0.27929688,0.020568848,-0.34936523,0.25976562,0.9741211,-0.15197754,0.10913086,1.0595703,-0.1385498,-0.2644043,-0.41796875,-0.54541016,-0.22619629,-0.6538086,-1.09375,-0.34643555,-1.0107422,0.0143966675,0.64160156,-1.4560547,-0.38256836,-0.76416016,1.1298828,1.0029297,0.57421875,-0.65527344,0.24609375,-0.42407227,1.3896484,-0.3125,-0.8276367,-0.45410156,0.48632812,1.4169922,0.0914917,-0.6699219,0.7368164,1.0009766,0.7036133,-0.8535156,-0.43041992,-0.93408203,1.2050781,-0.23449707,-0.14697266,-1.9912109,-0.09716797,-0.65625,-0.90625,0.6098633,-0.7602539,-0.5727539,1.0488281,1.3779297,0.68603516,-0.8808594,1.0185547,-0.6147461,0.13293457,-1.6611328,-0.2602539,-1.1240234,-0.35717773,1.0019531,0.5307617,0.5004883,-0.22802734,1.4697266,-0.23339844,0.6303711,